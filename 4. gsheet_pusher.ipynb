# %%
import pandas as pd, numpy as np
import itertools, requests, json

# %%
locs=pd.read_excel('data/szekelyhon_data.xlsx')

# %%
df
# Out:
#      Unnamed: 0  index       date                hudate  \
# 0             0      0 2006-04-07     2006. április 07.
# 1             1      1 2006-04-11     2006. április 11.
# 2             2      2 2006-06-13      2006. június 13.
# 3             3      3 2006-08-28   2006. augusztus 28.
# 4             4      4 2007-04-26     2007. április 26.
# 5             5      5 2007-06-26      2007. június 26.
# 6             6      5 2007-06-26      2007. június 26.
# 7             7      5 2007-06-26      2007. június 26.
# 8             8      5 2007-06-26      2007. június 26.
# 9             9      6 2007-07-23      2007. július 23.
# 10           10      7 2007-11-01    2007. november 01.
# 11           11      8 2008-07-08      2008. július 08.
# 12           12      8 2008-07-08      2008. július 08.
# 13           13      8 2008-07-08      2008. július 08.
# 14           14      8 2008-07-08      2008. július 08.
# 15           15      8 2008-07-08      2008. július 08.
# ...
