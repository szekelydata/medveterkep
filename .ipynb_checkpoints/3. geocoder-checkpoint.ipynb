# %%
import pandas as pd, numpy as np
import itertools, requests, json

# %%
dm=pd.read_excel('data/szekelyhon_medve.xlsx')
dc=pd.read_excel('data/szekelyhon_medve_curated.xlsx')
lm=pd.read_excel('data/szekelyhon_locs_curated.xlsx')

# %%
dc=dc[(dc['duplicate']!=1)&(dc['relevant']==1)]

# %%
dc["uid"] = dc["title"].map(str) + dc["content"]
dm["uid"] = dm["title"].map(str) + dm["content"]
lm["uid"] = lm["title"].map(str) + lm["content"]

# %%
dc=dc.set_index('uid')
dm=dm.set_index('uid')
lm=lm.set_index('uid')

# %%
dmi=dm.loc[dc.index.dropna()]

# %%
df=dmi.merge(dc).drop_duplicates()

# %%
dl=df.merge(lm)

# %% [markdown]
# Working df ready. Now infer location.

# %%
to_geo=[i.split(',') for i in dl['actual_locs'].unique() if str(i)!='nan']

# %%
to_geo=[i.strip() for i in list(itertools.chain.from_iterable(to_geo))]

# %% [markdown]
# Load HU names

# %%
coords=json.loads(open('geo/huncoords.json','r').read())
megyek=json.loads(open('geo/megyek.json','r').read())

# %%
data=[]
header=['index']
for i in dl.iteritems():
    header.append(i[0])
header.append('geo_loc')
header.append('latitude')
header.append('longitude')
header.append('id')
for i in dl.T.iteritems():
    dummy=[i[0]]
    for j in range(len(i[1])):
        if j==(len(i[1])-1):
            dummy.append(i[1][j])
            dummy.append('')
            dummy.append('')
            dummy.append('')
            dummy.append('')
            dtime=str(dummy[1])[:10]
            if dtime=='nan': dtime=u'N/A' 
            if str(i[1][j])!='nan':    
                for k in i[1][j].split(','):
                    tk=k.strip().replace('[','').replace(']','').replace("'",'')
                    dummy[-4]=tk
                    dummy[-3]=coords[tk][0]
                    dummy[-2]=coords[tk][1]
                    #dummy[-1]=str(dummy[-3])+' ('+str(dummy[0]+1)+')\n'+dtime
                    dummy[-1]=str(dummy[-4])+', '+dtime
                    data.append(list(dummy))                    
            else:
                dummy[-1]=u'N/A' +', '+dtime
                data.append(list(dummy))
        else: 
            dummy.append(i[1][j])

# %%
df=pd.DataFrame(data)
df.columns=header
df
# Out:
#     index  Unnamed: 0       date             hudate  \
# 0       0           0 2019-03-06  2019. március 06.
# 1       1           1 2019-03-16  2019. március 16.
# 2       2           2 2019-03-20  2019. március 20.
# 3       3           3 2019-03-20  2019. március 20.
# 4       4           4 2019-03-22  2019. március 22.
# 5       5           5 2019-03-23  2019. március 23.
# 6       6           6 2019-03-25  2019. március 25.
# 7       7           7 2019-03-26  2019. március 26.
# 8       8           8 2019-03-26  2019. március 26.
# 9       9           9 2019-03-27  2019. március 27.
# 10     10          10 2019-03-27  2019. március 27.
# 11     11          11 2019-03-27  2019. március 27.
# 12     12          12 2019-03-27  2019. március 27.
# 13     13          13 2019-03-27  2019. március 27.
# 14     14          14 2019-03-30  2019. március 30.
# 15     15          15 2019-04-06  2019. április 06.
# 16     16          16 2019-04-07  2019. április 07.
# 17     17          17 2019-04-17  2019. április 17.
#
#                                                  link  \
# 0   https://szekelyhon.ro/aktualis/meg-a-rokak-is-...
# 1   https://szekelyhon.ro/aktualis/elpusztult-az-u...
# 2   https://szekelyhon.ro/aktualis/ujabb-bocsot-sz...
# 3   https://szekelyhon.ro/aktualis/elesben-a-ro-al...
# 4   https://szekelyhon.ro/aktualis/nem-elte-tul-a-...
# 5   https://szekelyhon.ro/aktualis/engedelyezik-a-...
# 6   https://szekelyhon.ro/aktualis/nyomozas-indult...
# 7   https://szekelyhon.ro/aktualis/ha-blecsillapod...
# 8   https://szekelyhon.ro/aktualis/a-medvehelyzet-...
# 9   https://szekelyhon.ro/aktualis/adomanygyujtes-...
# 10  https://szekelyhon.ro/aktualis/villanypasztort...
# 11  https://szekelyhon.ro/aktualis/neveloszulot-ke...
# 12  https://szekelyhon.ro/aktualis/video-a-medvero...
# 13           https://szekelyhon.ro/aktualis/sokamedve
# 14  https://szekelyhon.ro/aktualis/szekelyfoldi-me...
# 15  https://szekelyhon.ro/aktualis/medvetamadasok-...
# 16  https://szekelyhon.ro/aktualis/halomra-olte-a-...
# 17  https://szekelyhon.ro/aktualis/legalabb-tizeno...
#
#                                                 image  category  icategory  \
# 0   https://media.szekelyhon.ro/pictures/udvarhely...  aktualis  udvarhely
# 1   https://media.szekelyhon.ro/pictures/udvarhely...  aktualis  udvarhely
# 2   https://media.szekelyhon.ro/pictures/agerpres/...  aktualis   agerpres
# 3   https://media.szekelyhon.ro/pictures/csik/aktu...  aktualis       csik
# 4   https://media.szekelyhon.ro/pictures/udvarhely...  aktualis  udvarhely
# 5   https://media.szekelyhon.ro/pictures/udvarhely...  aktualis  udvarhely
# 6   https://media.szekelyhon.ro/pictures/udvarhely...  aktualis  udvarhely
# 7   https://media.szekelyhon.ro/pictures/udvarhely...  aktualis  udvarhely
# 8   https://media.szekelyhon.ro/pictures/agerpres/...  aktualis   agerpres
# 9   https://media.szekelyhon.ro/pictures/udvarhely...  aktualis  udvarhely
# 10  https://media.szekelyhon.ro/pictures/csik/aktu...  aktualis       csik
# 11  https://media.szekelyhon.ro/pictures/udvarhely...  aktualis  udvarhely
# 12  https://media.szekelyhon.ro/pictures/udvarhely...  aktualis  udvarhely
# 13  https://media.szekelyhon.ro/pictures/udvarhely...  aktualis  udvarhely
# 14  https://media.szekelyhon.ro/pictures/udvarhely...  aktualis  udvarhely
# 15  https://media.szekelyhon.ro/pictures/agerpres/...  aktualis   agerpres
# 16  https://media.szekelyhon.ro/pictures/agerpres/...  aktualis   agerpres
# 17  https://media.szekelyhon.ro/pictures/udvarhely...  aktualis  udvarhely
#
#                                        tags  \
# 0             ['medve', 'Székelyudvarhely']
# 1                ['medve', 'Udvarhelyszék']
# 2                  ['medve', 'Tusnádfürdő']
# 3             ['medve', 'Sepsiszentgyörgy']
# 4                ['medve', 'Udvarhelyszék']
# 5                ['medve', 'Udvarhelyszék']
# 6   ['medve', 'Rendőrség', 'Udvarhelyszék']
# 7                ['medve', 'Udvarhelyszék']
# 8             ['medve', 'Sepsiszentgyörgy']
# 9                ['Hargita megye', 'medve']
# 10       ['Csíkszereda', 'Kórház', 'medve']
# 11               ['medve', 'Udvarhelyszék']
# 12               ['medve', 'Udvarhelyszék']
# 13                        ['Publicisztika']
# 14                 ['medve', 'Székelyföld']
# 15                 ['Maros megye', 'medve']
# 16               ['medve', 'Udvarhelyszék']
# 17            ['medve', 'Székelyudvarhely']
#
#                                                 title  ... relevant  severity  \
# 0   Még a rókák is kerülik az Udvarhelyhez közeli ...  ...        1         0
# 1   Elpusztult az Újszékely határában elgázolt med...  ...        1         1
# 2   Újabb bocsot szabadítottak ki az egyik tusnádf...  ...        1         1
# 3   Élesben a Ro-Alert: medve miatt riasztották a ...  ...        1         0
# 4   Nem élte túl a kőrispataki medvetámadást az ál...  ...        1         3
# 5   Engedélyezik a kőrispataki férfit halálosan me...  ...        1         0
# 6        Nyomozás indult a halálos medvetámadás miatt  ...        1         0
# 7   Ha „lecsillapodik” a kőrispataki medve, nem le...  ...        1         0
# 8   A medvehelyzet visszásságaira hívják fel a fig...  ...        1         0
# 9   Adománygyűjtés a kőrispataki medvetámadásban á...  ...        1         0
# 10  Villanypásztort szereltek a Csíkszeredai Megye...  ...        1         0
# 11  Nevelőszülőt keresnek a medvetámadás miatt fél...  ...        1         0
# 12  Videó a kőrispataki medvéről és a támadás hely...  ...        1         1
# 13                                         #Sokamedve  ...        1         0
# 14  Székelyföldi medveradar – térképen összegzik a...  ...        1         0
# 15  Medvetámadások után helyszíni terepszemlét tar...  ...        1         0
# 16                    Halomra ölte a birkákat a medve  ...        1         2
# 17   Legalább tizenöt medve jár be Székelyudvarhelyre  ...        1         0
#
#     deaths  duplicate    predicted_locs       actual_locs           geo_loc  \
# 0        0          0  Székelyudvarhely  Székelyudvarhely  Székelyudvarhely
# 1        0          0         Újszékely         Újszékely         Újszékely
# 2        0          0       Tusnádfürdő       Tusnádfürdő       Tusnádfürdő
# 3        0          0  Sepsiszentgyörgy  Sepsiszentgyörgy  Sepsiszentgyörgy
# 4        1          0        Kőrispatak        Kőrispatak        Kőrispatak
# 5        0          0        Kőrispatak        Kőrispatak        Kőrispatak
# 6        0          0        Kőrispatak        Kőrispatak        Kőrispatak
# 7        0          0        Kőrispatak        Kőrispatak        Kőrispatak
# 8        0          0  Sepsiszentgyörgy  Sepsiszentgyörgy  Sepsiszentgyörgy
# 9        0          0        Kőrispatak        Kőrispatak        Kőrispatak
# 10       0          0       Csíkszereda       Csíkszereda       Csíkszereda
# 11       0          0        Kőrispatak        Kőrispatak        Kőrispatak
# 12       0          0        Kőrispatak        Kőrispatak        Kőrispatak
# 13       0          0        Kőrispatak               NaN
# 14       0          0       Székelyvaja               NaN
# 15       0          0        Szászrégen        Idecspatak        Idecspatak
# 16      14          0               NaN      Szentábrahám      Szentábrahám
# 17       0          0  Székelyudvarhely  Székelyudvarhely  Székelyudvarhely
#
#    latitude longitude                    id
# 0    46.305   25.2926   Székelyudvarhely, 0
# 1   46.2608   24.9732          Újszékely, 1
# 2   46.1461    25.857        Tusnádfürdő, 2
# 3   45.8609   25.7886   Sepsiszentgyörgy, 3
# 4   46.4178   24.9704         Kőrispatak, 4
# 5   46.4178   24.9704         Kőrispatak, 5
# 6   46.4178   24.9704         Kőrispatak, 6
# 7   46.4178   24.9704         Kőrispatak, 7
# 8   45.8609   25.7886   Sepsiszentgyörgy, 8
# 9   46.4178   24.9704         Kőrispatak, 9
# 10  46.3696   25.7954       Csíkszereda, 10
# 11  46.4178   24.9704        Kőrispatak, 11
# 12  46.4178   24.9704        Kőrispatak, 12
# 13                                  N/A, 13
# 14                                  N/A, 14
# 15  46.8533   24.8191        Idecspatak, 15
# 16  46.3347   25.0091      Szentábrahám, 16
# 17   46.305   25.2926  Székelyudvarhely, 17
#
# [18 rows x 21 columns]

# %% [markdown]
# Save data for loading in viz app

# %%
df['checked']=''
df['exact_loc']=0

# %%
df=df[['checked',
    'date',
    'link',
    'image',
    'title',
    'content',
    'relevant',
    'severity',
    'deaths',
    'duplicate',
    'geo_loc',
    'exact_loc',
    'latitude',
    'longitude']].set_index('checked')

# %%
#PowerBI exploration data
df.to_excel('data/szekelyhon_data.xlsx')
